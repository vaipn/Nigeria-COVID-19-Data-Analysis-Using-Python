# %% [markdown]
# ### Task 1 - Data Collection
# Here you will obtain the required data for the analysis. As described in the project instructions, you will perform a web scrap to obtain data from the NCDC website, import data from the John Hopkins repository, and import the provided external data.

# %% [markdown]
# ### A - NCDC Website scrap
# Website - https://covid19.ncdc.gov.ng/

# %%
# Write Your Code Below
# Import all libraries in this cell
import requests
import numpy as np
import urllib.request
import pandas as pd
import csv
from bs4 import BeautifulSoup
import seaborn as sns
sns.set_style("darkgrid")
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.colors
# %matplotlib inline
plt.style.use('fivethirtyeight')  
import warnings
warnings.filterwarnings('ignore')

# %%
# Save the data to a DataFrame object.
url_ncdc='https://covid19.ncdc.gov.ng'
df=pd.read_html(url_ncdc)
ncdc=df[0]

# %% [markdown]
# ### B - John Hopkins Data Repository
# Here you will obtain data from the John Hopkins repository. Your task here involves saving the data from the GitHub repo link to DataFrame for further analysis. Find the links below.
# * Global Daily Confirmed Cases - Click [Here](https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv)
# * Global Daily Recovered Cases - Click [Here](https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv)
# * Global Daily Death Cases - Click [Here](https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv)

# %%
#1. Daily Confirmed Cases
url1='https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
conf_cases=pd.read_csv(url1, index_col="Country/Region")
#2 Daily Recovered Cases
url2='https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv'
reco_cases=pd.read_csv(url2, index_col="Country/Region")
#3. Daily Death Cases
url3='https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'
deat_cases=pd.read_csv(url3, index_col="Country/Region")

# %% [markdown]
# ### C - External Data
# * Save the external data to a DataFrame
# * External Data includes but not limited to: `covid_external.csv`, `Budget data.csv`, `RealGDP.csv`

# %%
covid_external=pd.read_csv('covid_external.csv')
budget_data=pd.read_csv('Budget data.csv')
realGDP=pd.read_csv('RealGDP.csv')

# %% [markdown]
# ### Task 2 - View the data
# Obtain basic information about the data using the `head()` and `info()` method.

# %%
reco_cases.head()
# Out:
#                Province/State       Lat       Long  1/22/20  1/23/20  1/24/20  \
# Country/Region
# Afghanistan               NaN  33.93911  67.709953        0        0        0
# Albania                   NaN  41.15330  20.168300        0        0        0
# Algeria                   NaN  28.03390   1.659600        0        0        0
# Andorra                   NaN  42.50630   1.521800        0        0        0
# Angola                    NaN -11.20270  17.873900        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  5/6/21  5/7/21  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...   53961   54019
# Albania               0        0        0        0  ...  114362  115253
# Algeria               0        0        0        0  ...   86007   86149
# Andorra               0        0        0        0  ...   12900   12936
# ...

# %%
conf_cases.head()
# Out:
#                Province/State       Lat       Long  1/22/20  1/23/20  1/24/20  \
# Country/Region
# Afghanistan               NaN  33.93911  67.709953        0        0        0
# Albania                   NaN  41.15330  20.168300        0        0        0
# Algeria                   NaN  28.03390   1.659600        0        0        0
# Andorra                   NaN  42.50630   1.521800        0        0        0
# Angola                    NaN -11.20270  17.873900        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  5/6/21  5/7/21  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...   61162   61455
# Albania               0        0        0        0  ...  131510  131577
# Algeria               0        0        0        0  ...  123473  123692
# Andorra               0        0        0        0  ...   13363   13390
# ...

# %%
deat_cases.head()
# Out:
#                Province/State       Lat       Long  1/22/20  1/23/20  1/24/20  \
# Country/Region
# Afghanistan               NaN  33.93911  67.709953        0        0        0
# Albania                   NaN  41.15330  20.168300        0        0        0
# Algeria                   NaN  28.03390   1.659600        0        0        0
# Andorra                   NaN  42.50630   1.521800        0        0        0
# Angola                    NaN -11.20270  17.873900        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  5/6/21  5/7/21  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...    2664    2673
# Albania               0        0        0        0  ...    2406    2408
# Algeria               0        0        0        0  ...    3307    3315
# Andorra               0        0        0        0  ...     127     127
# ...

# %%
reco_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, Afghanistan to Zimbabwe
# Columns: 483 entries, Province/State to 5/15/21
# dtypes: float64(2), int64(480), object(1)
# memory usage: 981.1+ KB

# %%
conf_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 275 entries, Afghanistan to Zimbabwe
# Columns: 483 entries, Province/State to 5/15/21
# dtypes: float64(2), int64(480), object(1)
# memory usage: 1.0+ MB

# %%
deat_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 275 entries, Afghanistan to Zimbabwe
# Columns: 483 entries, Province/State to 5/15/21
# dtypes: float64(2), int64(480), object(1)
# memory usage: 1.0+ MB

# %%
deat_cases.head()
# Out:
#                Province/State       Lat       Long  1/22/20  1/23/20  1/24/20  \
# Country/Region
# Afghanistan               NaN  33.93911  67.709953        0        0        0
# Albania                   NaN  41.15330  20.168300        0        0        0
# Algeria                   NaN  28.03390   1.659600        0        0        0
# Andorra                   NaN  42.50630   1.521800        0        0        0
# Angola                    NaN -11.20270  17.873900        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  5/6/21  5/7/21  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...    2664    2673
# Albania               0        0        0        0  ...    2406    2408
# Algeria               0        0        0        0  ...    3307    3315
# Andorra               0        0        0        0  ...     127     127
# ...

# %% [markdown]
# ### Task 3 - Data Cleaning and Preparation
# From the information obtained above, you will need to fix the data format.
# <br>
# Examples:
# * Convert to appropriate data type.
# * Rename the columns of the scraped data.
# * Remove comma(,) in numerical data
# * Extract daily data for Nigeria from the Global daily cases data

# %% [markdown]
# TODO A - Clean the scraped data

# %%
#Dropped the column with null entries
reco_cases.drop(columns='Province/State',inplace=True)
conf_cases.drop(columns='Province/State',inplace=True)
deat_cases.drop(columns='Province/State',inplace=True)

# %%
#Extracting daily data for Nigeria from the Global daily cases data
naija_deat_cases=deat_cases.loc["Nigeria"]
naija_conf_cases=conf_cases.loc["Nigeria"]
naija_reco_cases=reco_cases.loc["Nigeria"]

# %%
naija_reco_cases
# Out:
# Lat             9.0820
# Long            8.6753
# 1/22/20         0.0000
# 1/23/20         0.0000
# 1/24/20         0.0000
#               ...
# 5/11/21    156358.0000
# 5/12/21    156374.0000
# 5/13/21    156387.0000
# 5/14/21    156399.0000
# 5/15/21    156412.0000
# Name: Nigeria, Length: 482, dtype: float64

# %%
#Excluding Lattitude and Longitude
naija_reco_cases=naija_reco_cases[2:]
naija_conf_cases=naija_conf_cases[2:]
naija_deat_cases=naija_deat_cases[2:]

# %%
#Adding an index and converting the series to a dataframe
naija_reco_cases=naija_reco_cases.reset_index()
naija_conf_cases=naija_conf_cases.reset_index()
naija_deat_cases=naija_deat_cases.reset_index()

# %%
naija_reco_cases
# Out:
#        index   Nigeria
# 0    1/22/20       0.0
# 1    1/23/20       0.0
# 2    1/24/20       0.0
# 3    1/25/20       0.0
# 4    1/26/20       0.0
# ..       ...       ...
# 475  5/11/21  156358.0
# 476  5/12/21  156374.0
# 477  5/13/21  156387.0
# 478  5/14/21  156399.0
# 479  5/15/21  156412.0
#
# [480 rows x 2 columns]

# %%
#Converting to appropriate datatypes
naija_reco_cases=naija_reco_cases.astype({"index":"datetime64","Nigeria":"int64"})
naija_conf_cases=naija_conf_cases.astype({"index":"datetime64","Nigeria":"int64"})
naija_deat_cases=naija_deat_cases.astype({"index":"datetime64","Nigeria":"int64"})

# %%
naija_reco_cases
# Out:
#          index  Nigeria
# 0   2020-01-22        0
# 1   2020-01-23        0
# 2   2020-01-24        0
# 3   2020-01-25        0
# 4   2020-01-26        0
# ..         ...      ...
# 475 2021-05-11   156358
# 476 2021-05-12   156374
# 477 2021-05-13   156387
# 478 2021-05-14   156399
# 479 2021-05-15   156412
#
# [480 rows x 2 columns]

# %%
naija_conf_cases
# Out:
#          index  Nigeria
# 0   2020-01-22        0
# 1   2020-01-23        0
# 2   2020-01-24        0
# 3   2020-01-25        0
# 4   2020-01-26        0
# ..         ...      ...
# 475 2021-05-11   165515
# 476 2021-05-12   165559
# 477 2021-05-13   165612
# 478 2021-05-14   165661
# 479 2021-05-15   165702
#
# [480 rows x 2 columns]

# %% [markdown]
# TODO B - Get a Pandas DataFrame for Daily Confirmed Cases in Nigeria. Columns are Date and Cases

# %%
naija_conf_cases.rename(columns={"index":"Date","Nigeria":"Cases"},inplace=True)

# %%
naija_conf_cases
# Out:
#           Date   Cases
# 0   2020-01-22       0
# 1   2020-01-23       0
# 2   2020-01-24       0
# 3   2020-01-25       0
# 4   2020-01-26       0
# ..         ...     ...
# 475 2021-05-11  165515
# 476 2021-05-12  165559
# 477 2021-05-13  165612
# 478 2021-05-14  165661
# 479 2021-05-15  165702
#
# [480 rows x 2 columns]

# %% [markdown]
# TODO C - Get a Pandas DataFrame for Daily Recovered Cases in Nigeria. Columns are Date and Cases

# %%
naija_reco_cases.rename(columns={"index":"Date","Nigeria":"Cases"},inplace=True)

# %%
naija_reco_cases
# Out:
#           Date   Cases
# 0   2020-01-22       0
# 1   2020-01-23       0
# 2   2020-01-24       0
# 3   2020-01-25       0
# 4   2020-01-26       0
# ..         ...     ...
# 475 2021-05-11  156358
# 476 2021-05-12  156374
# 477 2021-05-13  156387
# 478 2021-05-14  156399
# 479 2021-05-15  156412
#
# [480 rows x 2 columns]

# %% [markdown]
# TODO D - Get a Pandas DataFrame for Daily Death Cases in Nigeria. Columns are Date and Cases

# %%
naija_deat_cases.rename(columns={"index":"Date","Nigeria":"Cases"},inplace=True)

# %%
naija_deat_cases
# Out:
#           Date  Cases
# 0   2020-01-22      0
# 1   2020-01-23      0
# 2   2020-01-24      0
# 3   2020-01-25      0
# 4   2020-01-26      0
# ..         ...    ...
# 475 2021-05-11   2065
# 476 2021-05-12   2066
# 477 2021-05-13   2066
# 478 2021-05-14   2066
# 479 2021-05-15   2066
#
# [480 rows x 2 columns]

# %% [markdown]
# ### Task 4 - Analysis
# Here you will perform some analyses on the datasets. You are welcome to communicate findings in charts and summary.
# <br>
# We have included a few TODOs to help with your analysis. However, do not let this limit your approach, feel free to include more, and be sure to support your findings with chart and summary

# %%
ncdc
# Out:
#    States Affected  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 0            Lagos                         58713                         1284
# 1              FCT                         19841                          571
# 2           Kaduna                          9068                            3
# 3          Plateau                          9060                            1
# 4           Rivers                          7169                           28
# 5              Oyo                          6855                            2
# 6              Edo                          4907                            7
# 7             Ogun                          4680                            3
# 8             Kano                          3967                            8
# 9             Ondo                          3248                         1105
# 10           Kwara                          3123                            1
# ...

# %%
ncdc.dtypes
# Out:
# States Affected                 object
# No. of Cases (Lab Confirmed)     int64
# No. of Cases (on admission)      int64
# No. Discharged                   int64
# No. of Deaths                    int64
# dtype: object

# %% [markdown]
# TODO A - Generate a plot that shows the Top 10 states in terms of Confirmed Covid cases by Laboratory test

# %%
ncdc.sort_values(by='No. of Cases (Lab Confirmed)', ascending=False)[:10].plot.barh(x='States Affected',y='No. of Cases (Lab Confirmed)',color='orange',title='Top 10 states in terms of Confirmed Covid-19 cases by Laboratory test')
# Out:
# <AxesSubplot:title={'center':'Top 10 states in terms of Confirmed Covid-19 cases by Laboratory test'}, ylabel='States Affected'>

# %% [markdown]
# Lagos State recorded the most number of cases, more than two times the number of confirmed cases in FCT (the State with the second highest number of confirmed cases).

# %% [markdown]
# TODO B - Generate a plot that shows the Top 10 states in terms of Discharged Covid cases. Hint - Sort the values

# %%
ncdc.sort_values(by='No. Discharged', ascending=False)[:10].plot.barh(x='States Affected',y='No. Discharged',color='green',title='Top 10 states in terms of Number of People Discharged')
# Out:
# <AxesSubplot:title={'center':'Top 10 states in terms of Number of People Discharged'}, ylabel='States Affected'>

# %% [markdown]
# Nine (the top nine) of the top ten retained the same position on both the recorded cases and the discharged cases.

# %% [markdown]
# TODO D - Plot the top 10 Death cases

# %%
ncdc.sort_values(by='No. of Deaths', ascending=False)[:10].plot.barh(x='States Affected',y=[4],color='red',title='Top 10 states in terms of Number of Death Cases')
# Out:
# <AxesSubplot:title={'center':'Top 10 states in terms of Number of Death Cases'}, ylabel='States Affected'>

# %% [markdown]
# #### Of the top 10 states in terms of lab confirmed covid-19 cases recorded in each state, which state did the most percentage die?

# %%
ten_sorted=ncdc.sort_values(by='No. of Cases (Lab Confirmed)', ascending=False)[:10]
ten_sorted['percentage']=(ten_sorted['No. of Deaths']/ten_sorted['No. of Cases (Lab Confirmed)'])*100
ten_sorted['percentage']
# Out:
# 0    0.747705
# 1    0.836651
# 2    0.716806
# 3    0.629139
# 4    1.408844
# 5    1.808899
# 6    3.770124
# 7    1.068376
# 8    2.772876
# 9    1.939655
# Name: percentage, dtype: float64

# %%
norm=plt.Normalize(ten_sorted['percentage'].values.min(),ten_sorted['percentage'].values.max())
colors=plt.cm.autumn_r(norm(ten_sorted.sort_values(by='percentage')['percentage'].values))
ten_sorted.sort_values(by='percentage').plot.bar(x='States Affected',y='percentage',xlabel='States',ylabel='Percentage (%) of deaths',yticks=(np.arange(0.0, 4.5, step=0.5)),legend=False,color=colors)
# Out:
# <AxesSubplot:xlabel='States', ylabel='Percentage (%) of deaths'>

# %% [markdown]
# Edo State - 3.77%.  Of every 100 lab confirmed cases in the State, about 4 of them died.

# %% [markdown]
# ### TODO E - Generate a line plot for the total daily confirmed, recovered and death cases in Nigeria

# %%
# Selcting all rows from the needed columns and saving to a dataframe
linencdc=ncdc.iloc[:,[1,3,4]]

# %%
linencdc.sum().plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### EXTRA TODO - Generate a plot that shows the Top 10 states in terms of Covid cases in admission. Hint - Sort the values

# %%
ncdc.sort_values(by='No. of Cases (on admission)', ascending=False)[:10].plot.barh(x='States Affected',y=[2],color={"turquoise"},title='Top 10 states in terms of No. of people in admission as at Thursday 7:59 am 08 May 2021')
# Out:
# <AxesSubplot:title={'center':'Top 10 states in terms of No. of people in admission as at Thursday 7:59 am 08 May 2021'}, ylabel='States Affected'>

# %% [markdown]
# TODO F -
# * Determine the daily infection rate, you can use the Pandas `diff` method to find the derivate of the total cases.
# * Generate a line plot for the above

# %%
naija_conf_cases['New Cases']=naija_conf_cases['Cases'].diff()

# %%
naija_conf_cases.dtypes
# Out:
# Date         datetime64[ns]
# Cases                 int64
# New Cases           float64
# dtype: object

# %%
naija_conf_cases.plot.line(x='New Cases', y='Date',legend=False)
# Out:
# <AxesSubplot:xlabel='New Cases'>

# %% [markdown]
# The all-time maximum infection rates were recorded between December 2020 and January 2021. However, the daily infection rate went on a decline shortly afterwards.

# %% [markdown]
# TODO G -
# * Calculate maximum infection rate for a day (Number of new cases)
# * Find the date

# %%
naija_conf_cases['New Cases'].max()
# Out:
# 2464.0

# %% [markdown]
# Maximum infection rate for a day is 2464.

# %%
naija_conf_cases.loc[naija_conf_cases['New Cases'].idxmax()]['Date']
# Out:
# Timestamp('2021-01-23 00:00:00')

# %% [markdown]
# The maximum infection rate for a day was on the 23rd of January, 2021.

# %% [markdown]
# TODO H - Determine the relationship between the external dataset and the NCDC COVID-19 dataset.
# Here you will generate a line plot of top 10 confirmed cases and the overall community vulnerability index on the same axis. From the graph, explain your observation.
# <br>
# Steps
# * Combine the two dataset together on a common column(states)
# * Create a new dataframe for plotting. This DataFrame will contain top 10 states in terms of confirmed cases i.e sort by confirmed cases. ** Hint: Check out Pandas [nlargest](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.nlargest.html) function. This [tutorial](https://cmdlinetips.com/2019/03/how-to-select-top-n-rows-with-the-largest-values-in-a-columns-in-pandas/) can help out **
# * Plot both variable on the same axis. Check out this [tutorial](http://kitchingroup.cheme.cmu.edu/blog/2013/09/13/Plotting-two-datasets-with-very-different-scales/)

# %%
ncdc
# Out:
#    States Affected  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 0            Lagos                         58713                         1284
# 1              FCT                         19841                          571
# 2           Kaduna                          9068                            3
# 3          Plateau                          9060                            1
# 4           Rivers                          7169                           28
# 5              Oyo                          6855                            2
# 6              Edo                          4907                            7
# 7             Ogun                          4680                            3
# 8             Kano                          3967                            8
# 9             Ondo                          3248                         1105
# 10           Kwara                          3123                            1
# ...

# %%
ncdc.rename(columns={'States Affected':'states'},inplace=True)
ncdc_external=ncdc.merge(covid_external,on='states')
ncdc_external
# Out:
#        states  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 0       Lagos                         58713                         1284
# 1         FCT                         19841                          571
# 2      Kaduna                          9068                            3
# 3     Plateau                          9060                            1
# 4      Rivers                          7169                           28
# 5         Oyo                          6855                            2
# 6         Edo                          4907                            7
# 7        Ogun                          4680                            3
# 8        Kano                          3967                            8
# 9        Ondo                          3248                         1105
# 10      Kwara                          3123                            1
# 11      Delta                          2627                          812
# ...

# %%
#Two states in the external dataset had incorrect spellings (reason why 2 states were missing after joining). 
#Correcting the spellings before joining the datasets. 
covid_external['states']=covid_external['states'].replace(['Nassarawa','Cross river'],['Nasarawa','Cross River'])
ncdc_external=ncdc.merge(covid_external,on='states')
ncdc_external
# Out:
#          states  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 0         Lagos                         58713                         1284
# 1           FCT                         19841                          571
# 2        Kaduna                          9068                            3
# 3       Plateau                          9060                            1
# 4        Rivers                          7169                           28
# 5           Oyo                          6855                            2
# 6           Edo                          4907                            7
# 7          Ogun                          4680                            3
# 8          Kano                          3967                            8
# 9          Ondo                          3248                         1105
# 10        Kwara                          3123                            1
# ...

# %%
ten_ncdc_external=ncdc_external.nlargest(10,'No. of Cases (Lab Confirmed)')

# %%
ten_ncdc_external
# Out:
#     states  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 0    Lagos                         58713                         1284
# 1      FCT                         19841                          571
# 2   Kaduna                          9068                            3
# 3  Plateau                          9060                            1
# 4   Rivers                          7169                           28
# 5      Oyo                          6855                            2
# 6      Edo                          4907                            7
# 7     Ogun                          4680                            3
# 8     Kano                          3967                            8
# 9     Ondo                          3248                         1105
#
#    No. Discharged  No. of Deaths         region  Population  \
# 0           56990            439     South West    13992000
# 1           19104            166  North Central     4865000
# ...

# %%
fi,ax=plt.subplots(nrows=1,ncols=2,figsize=(18,8),sharex='all')
ten_ncdc_external['No. of Cases (Lab Confirmed)'].plot.line(ax=ax[0])
plt.xticks(np.arange(0, 10, step=1),(ten_ncdc_external['states']))
ax[0].legend(['No. of Cases (Lab Confirmed)'])
#
ten_ncdc_external['Overall CCVI Index'].plot.line(ax=ax[1])
plt.legend(['Overall CCVI Index'])

# %% [markdown]
# Kaduna and Kano State, Though they haven't recorded relatively high number of cases yet, they have the highest overall CCVI Index (0.7 and 0.6 respectively) Indicating that the COVID-19 outbreak would have the most impact in the states - if the right measures aren't put in place.

# %% [markdown]
# #### Which States are the most vulnerable?

# %%
ten_vuln=ncdc_external.nlargest(10,'Overall CCVI Index')
ten_vuln
# Out:
#      states  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 16    Gombe                          2035                            5
# 33     Yobe                           436                           33
# 23    Borno                          1337                           99
# 30   Sokoto                           775                            0
# 31   Jigawa                           528                           20
# 35  Zamfara                           244                            3
# 22   Bauchi                          1549                           14
# 25  Adamawa                          1130                           12
# 26   Taraba                           992                            0
# 32    Kebbi                           450                           42
#
#     No. Discharged  No. of Deaths      region  Population  Overall CCVI Index  \
# 16            1986             44  North East     3692000                 1.0
# ...

# %%
ten_vuln.plot.bar(x='states',y='Overall CCVI Index',figsize=(10,7),title='Top 10 vulnerable states on a scale of 0 to 1 ')
plt.xticks(np.arange(0, 10, step=1),(ten_vuln['states']))
# Out:
# ([<matplotlib.axis.XTick at 0x9d0ecd0>,
# ...
#  [Text(0, 0, 'Gombe'),
#   Text(1, 0, 'Yobe'),
#   Text(2, 0, 'Borno'),
#   Text(3, 0, 'Sokoto'),
#   Text(4, 0, 'Jigawa'),
#   Text(5, 0, 'Zamfara'),
#   Text(6, 0, 'Bauchi'),
#   Text(7, 0, 'Adamawa'),
#   Text(8, 0, 'Taraba'),
#   Text(9, 0, 'Kebbi')])

# %% [markdown]
# TODO I - Determine the relationship between the external dataset and the NCDC COVID-19 dataset.
# * Here you will generate a regression plot between two variables to visualize the linear relationships - Confirmed Cases and Population Density.
# Hint: Check out Seaborn [Regression Plot](https://seaborn.pydata.org/generated/seaborn.regplot.html).
# * Provide a summary of your observation

# %%
sns.regplot(data=ncdc_external,x='Population Density',y='No. of Cases (Lab Confirmed)',color='g',scatter=False)
# Out:
# <AxesSubplot:xlabel='Population Density', ylabel='No. of Cases (Lab Confirmed)'>

# %% [markdown]
# The Population Density of each State is proportional to the total number of COVID-19 cases (lab confirmed) in each State. Therefore, the higher the Population Density on a scale of 0 to 1 the higher the chances of higher confirmed cases.

# %% [markdown]
# #### Whats the number of lab confirmed cases recorded in the 10 most vulnerable states currently?

# %%
ten_vuln.plot.line(x='states',y='No. of Cases (Lab Confirmed)',figsize=(10,7),title='Number of cases recorded in the 10 most vulnerable states')
plt.xticks(np.arange(0, 10, step=1),(ten_vuln['states']))
# Out:
# ([<matplotlib.axis.XTick at 0x9d909e8>,
# ...
#  [Text(0, 0, 'Gombe'),
#   Text(1, 0, 'Yobe'),
#   Text(2, 0, 'Borno'),
#   Text(3, 0, 'Sokoto'),
#   Text(4, 0, 'Jigawa'),
#   Text(5, 0, 'Zamfara'),
#   Text(6, 0, 'Bauchi'),
#   Text(7, 0, 'Adamawa'),
#   Text(8, 0, 'Taraba'),
#   Text(9, 0, 'Kebbi')])

# %% [markdown]
# These numbers are going to skyrocket if the right measures aren't put in place, because these states have High to Very High Overall CCVI Index scores.

# %% [raw]
# TODO J -
# * Provide more analyses by extending TODO G & H. Meaning, determine relationships between more features.
# * Provide a detailed summary of your findings.
# * Note that you can have as many as possible.

# %% [markdown]
# ### Extension of TODO G

# %%
naija_reco_cases['New Cases']=naija_reco_cases['Cases'].diff()
naija_deat_cases['New Cases']=naija_deat_cases['Cases'].diff()

# %%
naija_reco_cases
# Out:
#           Date   Cases  New Cases
# 0   2020-01-22       0        NaN
# 1   2020-01-23       0        0.0
# 2   2020-01-24       0        0.0
# 3   2020-01-25       0        0.0
# 4   2020-01-26       0        0.0
# ..         ...     ...        ...
# 475 2021-05-11  156358       40.0
# 476 2021-05-12  156374       16.0
# 477 2021-05-13  156387       13.0
# 478 2021-05-14  156399       12.0
# 479 2021-05-15  156412       13.0
#
# [480 rows x 3 columns]

# %%
#Maximum number of deaths in a day
naija_deat_cases['New Cases'].max()
# Out:
# 31.0

# %% [markdown]
# Maximum daily death rate is 31.

# %%
naija_deat_cases.loc[naija_deat_cases['New Cases'].idxmax()]['Date']
# Out:
# Timestamp('2020-06-16 00:00:00')

# %% [markdown]
# The maximum daily death rate was first recorded on the 16th of June, 2020.

# %%
naija_reco_cases['New Cases'].max()
# Out:
# 11188.0

# %% [markdown]
# Maximum daily recover rate is 11,188.

# %%
naija_reco_cases.loc[naija_reco_cases['New Cases'].idxmax()]['Date']
# Out:
# Timestamp('2020-08-04 00:00:00')

# %% [markdown]
# The maximum daily recover rate was first recorded on the 4th of August, 2020.

# %% [markdown]
# #### Extension of TODO H - Determine the relationship between the external dataset and the NCDC COVID-19 dataset. Here you will generate a line plot of top 10 vulnerable states cases and the overall community vulnerability index score on the same axis.

# %%
ten_vuln=ten_vuln.sort_values(by='No. of Cases (Lab Confirmed)')
ten_vuln.reset_index(inplace=True)
ten_vuln.drop(columns='index')
# Out:
#     states  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 0  Zamfara                           244                            3
# 1     Yobe                           436                           33
# 2    Kebbi                           450                           42
# 3   Jigawa                           528                           20
# 4   Sokoto                           775                            0
# 5   Taraba                           992                            0
# 6  Adamawa                          1130                           12
# 7    Borno                          1337                           99
# 8   Bauchi                          1549                           14
# 9    Gombe                          2035                            5
#
#    No. Discharged  No. of Deaths      region  Population  Overall CCVI Index  \
# 0             233              8  North West     4974000                 0.9
# ...

# %%
fi,ax=plt.subplots(nrows=8,ncols=2,figsize=(20,48),sharex='all')
ten_vuln['No. of Cases (Lab Confirmed)'].plot.line(ax=ax[0,0])
plt.xticks(np.arange(0, 10, step=1),(ten_vuln['states']))
ax[0,0].legend(['No. of Cases (Lab Confirmed)'])
ten_vuln['Socio-Economic'].plot.line(ax=ax[0,1])
ax[0,1].legend(['Socio-Economic Index Score'])
#
ten_vuln['No. of Cases (Lab Confirmed)'].plot.line(ax=ax[1,0])
ax[1,0].legend(['No. of Cases (Lab Confirmed)'])
ten_vuln['Population Density'].plot.line(ax=ax[1,1])
ax[1,1].legend(['Population Density'])
#
ten_vuln['No. of Cases (Lab Confirmed)'].plot.line(ax=ax[2,0])
ax[2,0].legend(['No. of Cases (Lab Confirmed)'])
ten_vuln[' Transport Availability'].plot.line(ax=ax[2,1])
ax[2,1].legend(['Transport Availability Index Score'])
#
ten_vuln['No. of Cases (Lab Confirmed)'].plot.line(ax=ax[3,0])
ax[3,0].legend(['No. of Cases (Lab Confirmed)'])
ten_vuln['Epidemiological'].plot.line(ax=ax[3,1])
ax[3,1].legend(['Epidemiological Index Score'])
#
ten_vuln['No. of Cases (Lab Confirmed)'].plot.line(ax=ax[4,0])
ax[4,0].legend(['No. of Cases (Lab Confirmed)'])
ten_vuln['Health System'].plot.line(ax=ax[4,1])
ax[4,1].legend(['Health System Index Score'])
#
ten_vuln['No. of Cases (Lab Confirmed)'].plot.line(ax=ax[5,0])
ax[5,0].legend(['No. of Cases (Lab Confirmed)'])
ten_vuln['Fragility'].plot.line(ax=ax[5,1])
ax[5,1].legend(['Fragility Index Score'])
#
ten_vuln['No. of Cases (Lab Confirmed)'].plot.line(ax=ax[6,0])
ax[6,0].legend(['No. of Cases (Lab Confirmed)'])
ten_vuln['Age'].plot.line(ax=ax[6,1],)
ax[6,1].legend(['Age Index Score'])
#
ten_vuln['No. of Cases (Lab Confirmed)'].plot.line(ax=ax[7,0])
ax[7,0].legend(['No. of Cases (Lab Confirmed)'])
ten_vuln['Acute IHR'].plot.line(ax=ax[7,1],)
ax[7,1].legend(['Acute IHR Index Score'])

# %% [markdown]
# #### Alarming themes in Zamfara State :
# * Acute IHR (High)
# * Fragility (High)
# * Health System (High)
# * Socioeconomic Status (Very High)
# * Transport Availability (High)
#
# #### Alarming themes in Yobe :
# * Acute IHR (High)
# * Fragility (Very High)
# * Socioeconomic Status (High)
# * Transport Availability (Very High)
#
# #### Alarming themes in Kebbi State
# * Acute IHR (High)
# * Health System (High)
# * Socioeconomic Status (High)
# * Transport Availability (High)
#
# #### Alarming themes in Jigawa State
# * Acute IHR (High)
# * Fragility (High)
# * Socioeconomic Status (High)
# * Transport Availability (High)
#
# #### Alarming themes in Sokoto State
# * Health System (High)
# * Socioeconomic Status (Very High)
# * Acute IHR (High)
# * Transport Availability (Very High)
#
# #### Alarming themes in Taraba State
# * Transport Availability (High)
# * Epidemiological Factors (High)
# * Socioeconomic Status (High)
# * Acute IHR (High)
# * Fragility (High)
#
# #### Alarming themes in Adamawa State
# * Acute IHR (Very High)
# * Fragility (High)
# * Health System (High)
# * Socioeconomic Status (High)
#
# #### Alarming themes in Borno State
# * Acute IHR (High)
# * Fragility (Very High)
# * Health System (Very High)
# * Socioeconomic Status (High)
# * Transport Availability (High)
#
# #### Alarming themes in Bauchi State
# * Socioeconomic Status (High)
# * Acute IHR (High)
# * Fragility (High)
# * Health System (High)
# * Transport Availability (High)
#
# #### Alarming themes in Gombe State
# * Transport Availability (High)
# * Socioeconomic Status (High)
# * Health System (High)
# * Fragility (High)
# * Acute IHR (High).
#
# ## Note:
# * Very High (1+)
# * High (0.70 - 0.99)

# %% [markdown]
# #### Which of the states would need external intervention the most?

# %%
# Matching the budget of the states with the states
ten_vuln=ten_vuln.merge(budget_data,on='states')

# %%
ten_vuln
# Out:
#    index   states  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 0     35  Zamfara                           244                            3
# 1     33     Yobe                           436                           33
# 2     32    Kebbi                           450                           42
# 3     31   Jigawa                           528                           20
# 4     30   Sokoto                           775                            0
# 5     26   Taraba                           992                            0
# 6     25  Adamawa                          1130                           12
# 7     23    Borno                          1337                           99
# 8     22   Bauchi                          1549                           14
# 9     16    Gombe                          2035                            5
#
#    No. Discharged  No. of Deaths      region  Population  Overall CCVI Index  \
# ...

# %%
# Generating a plot for the states budget
ten_vuln.plot.bar(x='states',y='Revised_budget (Bn)')
plt.legend(['Revised budget (Billion Naira)'])

# %% [markdown]
# Yobe State would need the most external support as their relatively lower budget might impede their response to addressing the themes and sub-themes

# %% [markdown]
# ### TODO L -
# Determine the effect of the Pandemic on the economy. To do this, you will compare the Real GDP value Pre-COVID-19 with Real GDP in 2020 (COVID-19 Period, especially Q2 2020)
# <br>
# Steps
# * From the Real GDP Data, generate a `barplot` using the GDP values for each year & quarters. For example: On x-axis you will have year 2017 and the bars will be values of each quarters(Q1-Q4). You expected to have subplots of each quarters on one graph.
# <br>
# Hint: Use [Pandas.melt](https://pandas.pydata.org/docs/reference/api/pandas.melt.html) to create your plot DataFrame
# * Set your quarter legend to lower left.
# * Using `axhline`, draw a horizontal line through the graph at the value of Q2 2020.
# * Write out your observation

# %%
realGDP
# Out:
#    Year           Q1           Q2           Q3           Q4
# 0  2014  15438679.50  16084622.31  17479127.58  18150356.45
# 1  2015  16050601.38  16463341.91  17976234.59  18533752.07
# 2  2016  15943714.54  16218542.41  17555441.69  18213537.29
# 3  2017  15797965.83  16334719.27  17760228.17  18598067.07
# 4  2018  16096654.19  16580508.07  18081342.10  19041437.59
# 5  2019  16434552.65  16931434.89  18494114.17  19530000.00
# 6  2020  16740000.00  15890000.00  17820000.00         0.00

# %%
meltd_realGDP=realGDP.melt(id_vars='Year',value_name='GDP',var_name='Quarters')

# %%
meltd_realGDP
# Out:
#     Year Quarters          GDP
# 0   2014       Q1  15438679.50
# 1   2015       Q1  16050601.38
# 2   2016       Q1  15943714.54
# 3   2017       Q1  15797965.83
# 4   2018       Q1  16096654.19
# 5   2019       Q1  16434552.65
# 6   2020       Q1  16740000.00
# 7   2014       Q2  16084622.31
# 8   2015       Q2  16463341.91
# 9   2016       Q2  16218542.41
# 10  2017       Q2  16334719.27
# 11  2018       Q2  16580508.07
# 12  2019       Q2  16931434.89
# 13  2020       Q2  15890000.00
# 14  2014       Q3  17479127.58
# 15  2015       Q3  17976234.59
# 16  2016       Q3  17555441.69
# 17  2017       Q3  17760228.17
# 18  2018       Q3  18081342.10
# 19  2019       Q3  18494114.17
# 20  2020       Q3  17820000.00
# 21  2014       Q4  18150356.45
# 22  2015       Q4  18533752.07
# 23  2016       Q4  18213537.29
# 24  2017       Q4  18598067.07
# 25  2018       Q4  19041437.59
# 26  2019       Q4  19530000.00
# 27  2020       Q4         0.00

# %%
groupd_meltd_realGDP=meltd_realGDP.groupby('Year')

# %%
# setting color and labels for the bars
q1=mpatches.Patch(color='green',label='Q1')
q2=mpatches.Patch(color='orange',label='Q2')
q3=mpatches.Patch(color='purple',label='Q3')
q4=mpatches.Patch(color='blue',label='Q4')

# %%
fig,axes=plt.subplots(nrows=7,ncols=1,figsize=(8,38))
color=['green','orange','purple','blue']
groupd_meltd_realGDP.get_group(2014).plot(x='Year',y='GDP',ax=axes[0],kind='bar',color=color)
groupd_meltd_realGDP.get_group(2015).plot.bar(x='Year',y='GDP',ax=axes[1],color=color)
groupd_meltd_realGDP.get_group(2016).plot.bar(x='Year',y='GDP',ax=axes[2],color=color)
groupd_meltd_realGDP.get_group(2017).plot.bar(x='Year',y='GDP',ax=axes[3],color=color)
groupd_meltd_realGDP.get_group(2018).plot.bar(x='Year',y='GDP',ax=axes[4],color=color)
groupd_meltd_realGDP.get_group(2019).plot.bar(x='Year',y='GDP',ax=axes[5],color=color)
groupd_meltd_realGDP.get_group(2020).plot.bar(x='Year',y='GDP',ax=axes[6],color=color)

# Adding legend to the plot
axes[0].legend(handles=[q1,q2,q3,q4],loc='lower left')
axes[1].legend(handles=[q1,q2,q3,q4],loc='lower left')
axes[2].legend(handles=[q1,q2,q3,q4],loc='lower left')
axes[3].legend(handles=[q1,q2,q3,q4],loc='lower left')
axes[4].legend(handles=[q1,q2,q3,q4],loc='lower left')
axes[5].legend(handles=[q1,q2,q3,q4],loc='lower left')
plt.legend(handles=[q1,q2,q3],loc='lower left')

# To display numbers in y axis as is in the dataframe (and not as shortened form - scientific)
axes[0].get_yaxis().get_major_formatter().set_scientific(False)
axes[1].get_yaxis().get_major_formatter().set_scientific(False)
axes[2].get_yaxis().get_major_formatter().set_scientific(False)
axes[3].get_yaxis().get_major_formatter().set_scientific(False)
axes[4].get_yaxis().get_major_formatter().set_scientific(False)
axes[5].get_yaxis().get_major_formatter().set_scientific(False)
axes[6].get_yaxis().get_major_formatter().set_scientific(False)

# Adding an horiontal line through the graph at the value of Q2 2020.
axes[6].axhline(y=15890000.00, color='black')

# %% [markdown]
# In previous years (before COVID-19 hit the country), the GDP growth each year used to increase gradually every quarter, whereas ater the hit of COVID-19 (precisely the Second Quarter of 2020) the GDP decreased in growth.

# %% [markdown]
# #### Whats the percentage of change of the gross domestic product between the first and second quarters?

# %%
# evaluating the percentage of change between Q1 and Q2
realGDP['percent']=((realGDP['Q1']-realGDP['Q2'])/realGDP['Q1']*100)*-1

# %%
realGDP
# Out:
#    Year           Q1           Q2           Q3           Q4   percent
# 0  2014  15438679.50  16084622.31  17479127.58  18150356.45  4.183925
# 1  2015  16050601.38  16463341.91  17976234.59  18533752.07  2.571496
# 2  2016  15943714.54  16218542.41  17555441.69  18213537.29  1.723738
# 3  2017  15797965.83  16334719.27  17760228.17  18598067.07  3.397611
# 4  2018  16096654.19  16580508.07  18081342.10  19041437.59  3.005928
# 5  2019  16434552.65  16931434.89  18494114.17  19530000.00  3.023400
# 6  2020  16740000.00  15890000.00  17820000.00         0.00 -5.077658

# %%
realGDP.plot.line(x='Year',y='percent',title='Percentage of change of the gross domestic product between the first quater and second quarters')
# Out:
# <AxesSubplot:title={'center':'Percentage of change of the gross domestic product between the first quater and second quarters'}, xlabel='Year'>

# %% [markdown]
# #### States reduced their initial budget due to the pandemic, but by about how much?

# %%
# determining the precentage of reduction
budget_data['percent_of_reduction']=(budget_data['Initial_budget (Bn)']-budget_data['Revised_budget (Bn)'])/budget_data['Initial_budget (Bn)']*100

# %%
budget_data['percent_of_reduction'].describe()
# Out:
# count    37.000000
# mean     29.769166
# std      13.140634
# min      12.704918
# 25%      23.444976
# 50%      27.826087
# 75%      36.774194
# max      86.627273
# Name: percent_of_reduction, dtype: float64

# %%
budget_data
# Out:
#          states  Initial_budget (Bn)  Revised_budget (Bn)  \
# 0          Abia               136.60               102.70
# 1       Adamawa               183.30               139.31
# 2     Akwa-Ibom               597.73               366.00
# 3       Anambra               137.10               112.80
# 4        Bauchi               167.20               128.00
# 5       Bayelsa               242.18               183.15
# 6         Benue               189.00               119.00
# 7         Borno               146.80               108.80
# 8   Cross River              1100.00               147.10
# 9         Delta               395.50               282.30
# 10       Ebonyi               178.40               131.80
# 11          Edo               179.20               128.80
# 12        Ekiti               124.50                91.10
# 13        Enugu               169.56               146.40
# 14        Gombe               130.83               107.40
# ...

# %% [markdown]
# * Katsina State had the least reduction after revision - 12.7%
# * Cross River State had the maximum budget reduction - 86.6%
# * All states reduced their initial budget by an average of about 30% due to the impact of COVID-19 on the economy

# %%
# generating an area plot showing the initial budget and revised budget of all 37 states.
budget_data.plot.area(stacked=False,x='states',figsize=(12,12))
plt.xticks(np.arange(0, 37, step=1),(budget_data['states']),rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0xb1904a8>,
# ...
#  [Text(0, 0, 'Abia'),
#   Text(1, 0, 'Adamawa'),
#   Text(2, 0, 'Akwa-Ibom'),
#   Text(3, 0, 'Anambra'),
#   Text(4, 0, 'Bauchi'),
#   Text(5, 0, 'Bayelsa'),
#   Text(6, 0, 'Benue'),
#   Text(7, 0, 'Borno'),
#   Text(8, 0, 'Cross River'),
#   Text(9, 0, 'Delta'),
#   Text(10, 0, 'Ebonyi'),
#   Text(11, 0, 'Edo'),
#   Text(12, 0, 'Ekiti'),
#   Text(13, 0, 'Enugu'),
#   Text(14, 0, 'Gombe'),
#   Text(15, 0, 'Imo'),
#   Text(16, 0, 'Jigawa'),
#   Text(17, 0, 'Kaduna'),
#   Text(18, 0, 'Kano'),
#   Text(19, 0, 'Katsina'),
#   Text(20, 0, 'Kebbi'),
#   Text(21, 0, 'Kogi'),
#   Text(22, 0, 'Kwara'),
#   Text(23, 0, 'Lagos'),
#   Text(24, 0, 'Nasarawa'),
#   Text(25, 0, 'Niger'),
#   Text(26, 0, 'Ogun'),
#   Text(27, 0, 'Ondo'),
#   Text(28, 0, 'Osun'),
#   Text(29, 0, 'Oyo'),
#   Text(30, 0, 'Plateau'),
#   Text(31, 0, 'Rivers'),
#   Text(32, 0, 'Sokoto'),
#   Text(33, 0, 'Taraba'),
#   Text(34, 0, 'Yobe'),
#   Text(35, 0, 'Zamfara'),
# ...
